# %%
import pandas as pd

prob_data = pd.read_excel('dbn_node_prob_1381.xlsx',
                              sheet_name='Probability',
                              names=['list', 'CPT'])

# %%
prob_data['CPT'] = list(map(lambda x: x.split(), prob_data['CPT']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_46936\456655090.py in <module>
# ----> 1 prob_data['CPT'] = list(map(lambda x: float(x.split()), prob_data['CPT']))
#
# ~\AppData\Local\Temp\ipykernel_46936\456655090.py in <lambda>(x)
# ----> 1 prob_data['CPT'] = list(map(lambda x: float(x.split()), prob_data['CPT']))
#
# AttributeError: 'list' object has no attribute 'split'

# %%
prob_data
# Out:
#                                         list  \
# 0                      P( (24, 0) | (54, 0))
# 1            P( (24, 1) | (24, 0), (54, 1) )
# 2                     P( (29, 0) | (60, 0) )
# 3            P( (29, 1) | (29, 0), (60, 1) )
# 4                     P( (35, 0) | (54, 0) )
# 5            P( (35, 1) | (35, 0), (54, 1) )
# 6                     P( (36, 1) | (36, 0) )
# 7                     P( (37, 0) | (55, 0) )
# 8              P( (37, 1) | (37, 0), (55, 1)
# 9                     P( (47, 0) | (60, 0) )
# 10           P( (47, 1) | (47, 0), (60, 1) )
# 11                    P( (52, 0) | (53, 0) )
# 12           P( (52, 1) | (52, 0), (53, 1) )
# 13                    P( (53, 0) | (54, 0) )
# 14           P( (53, 1) | (53, 0), (54, 1) )
# 15                    P( (54, 0) | (36, 0) )
# 16           P( (54, 1) | (36, 1), (54, 0) )
# 17                    P( (55, 0) | (54, 0) )
# 18          P( (55, 1) | (54, 1), (55, 0)  )
# 19                    P( (56, 0) | (55, 0) )
# 20           P( (56, 1) | (55, 1), (56, 0) )
# 21                    P( (57, 0) | (56, 0) )
# 22           P( (57, 1) | (56, 1), (57, 0) )
# 23           P( (60, 0) | (52, 0), (61, 0) )
# 24  P( (60, 1) | (52, 1), (60, 0), (61, 1) )
# 25                    P( (61, 0) | (53, 0) )
# 26            P( (61, 1) | (53, 1), (61, 0))
# 27                    P( (64, 0) | (56, 0) )
# 28            P( (64, 1) |(56, 1) ,(64, 0) )
# 29           P( (65, 0) | (57, 0), (64, 0) )
# 30  P( (65, 1) | (57, 1), (64, 1), (65, 0) )
#
#                                                   CPT
# 0                              [0.4142, 0, 0.5858, 1]
# 1        [1, 0.5858, 0.4142, 0, 0, 0.4142, 0.5858, 1]
# 2                              [0.4114, 0, 0.5886, 1]
# 3        [1, 0.5886, 0.4114, 0, 0, 0.4114, 0.5886, 1]
# 4                              [0.4212, 0, 0.5788, 1]
# 5        [1, 0.5788, 0.4212, 0, 0, 0.4212, 0.5788, 1]
# 6                                        [1, 0, 0, 1]
# 7                              [0.4170, 0, 0.5830, 1]
# 8        [1, 0.5830, 0.4170, 0, 0, 0.4170, 0.5830, 1]
# 9                              [0.4595, 0, 0.5405, 1]
# 10       [1, 0.5405, 0.4595, 0, 0, 0.4595, 0.5405, 1]
# 11                   [0.3713, 0.2391, 0.6287, 0.7609]
# 12  [0.7608, 0.3805, 0.3713, 0.2391, 0.2392, 0.610...
# 13                             [0.4525, 0, 0.5475, 1]
# 14       [1, 0.5475, 0.4525, 0, 0, 0.4525, 0.5475, 1]
# 15                             [0.3952, 0, 0.6048, 1]
# 16       [1, 0.6048, 0.3952, 0, 0, 0.3952, 0.6048, 1]
# 17                             [0.4252, 0, 0.5748, 1]
# 18       [1, 0.4252, 0.5748, 0, 0, 0.5748, 0.4252, 1]
# 19                             [0.4771, 0, 0.5229, 1]
# 20       [1, 0.4771, 0.5229, 0, 0, 0.5229, 0.4771, 1]
# 21                             [0.4854, 0, 0.5146, 1]
# 22       [1, 0.4854, 0.5146, 0, 0, 0.5146, 0.4854, 1]
# 23  [0.6379, 0.3281, 0.3098, 0.3621, 0.3621, 0.671...
# 24  [1, 0.6831, 0.6902, 0.3281, 0.6719, 0.3621, 0....
# 25                             [0.4579, 0, 0.5421, 1]
# 26       [1, 0.4579, 0.5421, 0, 0, 0.5421, 0.4579, 1]
# 27                             [0.4559, 0, 0.5441, 1]
# 28       [1, 0.4559, 0.5441, 0, 0, 0.5441, 0.4559, 1]
# 29       [1, 0.3264, 0.3133, 0, 0, 0.6736, 0.6867, 1]
# 30  [1, 0.6397, 0.6866, 0.3264, 0.6735, 0.3133, 0....
